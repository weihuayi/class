# %% [markdown]
# # 1. 方程

# %% [markdown]
# 含有未知量的等式称为**方程**.
#
# * 代数方程
# * 超越方程
# * 函数方程或泛函方程
#
# 多个方程联立称为**方程组**.

# %% [markdown]
# ##   代数方程(组)

# %% [markdown]
# 代数方程的未知量是数.
#
# 如一元 $n$ 次方程:
#
# $$
# x^n + a_1 x^{n-1} + \cdots + a_{n-1}x + a_n = 0
# $$
#
# 无理方程:
#
# $$ \sqrt{x^2 + 5} = 7 $$
#
# 方程组:
# $$
# \begin{cases}
# x+y = 7\\
# x-y = -1
# \end{cases}
# $$

# %% [markdown]
# ##  超越方程(组)

# %% [markdown]
# 等式中含有超越函数的方程称为**超越方程**. 如
#
# $$ \sin(x+5) = \cos x$$
#
# $$ e^x + 2^x = 5 $$
#
# 这些方程的解为实数, 个数可能是有限多个或无限多个.

# %% [markdown]
# ## 函数方程或泛函方程

# %% [markdown]
# * 未知量为函数
# * 方程的解为有限个或无穷多个函数
#
# $$ Z^2(t) + \sin^2 t = 1, Z(t) = \pm \cos t$$
# $$ Z^{\prime\prime} = 1, Z(t) = \frac{t^2}{2}+c_1t+c_2$$

# %% [markdown]
# # 2. 微分方程

# %% [markdown]
# 一个或几个包含自变量,未知函数以及未知函数的某些阶导数(或微商)的关系式,称之为**微分方程**.
#
# 1. $y^\prime = x^2$
# 1. $ r^2\frac{d^2u}{dr^2} + r\frac{du}{dr}+(r^2 - 1)u = 0$
# 1. $\frac{dy}{dx}+p(x)y = \theta(x)$
# 1. $F(x, y, y^\prime,\ldots, y^{(n)})=0$
# 1. $y^{(n)} = f(x, y, y^\prime, \ldots, y^{(n-1)})$
# 1. $\begin{cases}\frac{dx}{dt}=x+y\\\frac{dy}{dt}=x-y\end{cases}$
# 1. $\frac{\partial^2 u}{\partial x\partial y} = 0 $
# 1. $\frac{\partial^2 u}{\partial x\partial y} + \frac{\partial^2u}{\partial y^2} + \frac{\partial^2u}{\partial z^2} = -4$
# 1. $f^{\prime\prime}(x)=\sin x$
# 1. $f^{(2)}(x)=\sin x$

# %% [markdown]
# # 3. 微分方程模型

# %% [markdown]
# **例 1** 质量为m的物体在重力的作用下,沿铅直线下落,
# 物体下落距离 $s$ (向下为正)随时间 $t$ 而改变。在不考虑
# 空气阻力的情况下,试求出距离 $s$ 应满足的微分方程。

# %% [markdown]
# **解**: 设在时刻 $t$, 质量为 $m$ 的物体下落的距离为 $s(t)$, 由牛顿第二定律可得:
# $$
# m\frac{d^2s}{dt^2}=mg
# $$
# $$
# \frac{d^2s}{dt^2}=g
# $$
# 解得
# $$
# s(t) = \frac{1}{2}gt^2+c_1t+c_2
# $$

# %% [markdown]
# **例 2**:放射性元素镭因不断放射出各种射线而逐渐减少其质量,这种现象成为**衰变**,实验知镭的衰变率与其当时的衰变质量成比例。试求镭衰变的规律。

# %% [markdown]
# **解**: 设在任意时刻 $t$ 镭的质量为 $R(t)$,
# $$
# R^\prime(t) = kR(t)
# $$

# %% [markdown]
# **微分方程模型**: 含有自变量,未知函数及未知函数导数
# (或变化率)的关系式

# %% [markdown]
# #  4. 基本概念

# %% [markdown]
# * 常微分方程和偏微分方程
# * 一阶与高阶微分方程
# * 线性和非线性微分方程
# * 解和隐式解
# * 通解和特解
# * 积分曲线和积分曲线族
# * 微分方程的几何解释-----方向场

# %% [markdown]
# ## 常微分方程和偏微分方程

# %% [markdown]
# **常微分方程/ODE/** 在微分方程中, 自变量的个数只有一个的微分方程.
#
# **偏微分方程 /PDE/** 自变量的个数有两个或两个以上的微分方程.

# %% [markdown]
# ## 一阶与高阶微分方程

# %% [markdown]
# **微分方程的阶 /Order/** 在一个微分方程中所出现的未知函数的导数的最高阶数 $n$ 。
#
# 当 $n=1$ 时,称为一阶微分方程.
#
# 当 $n>1$ 时,称为高阶微分方程.

# %% [markdown]
# * $F(x, y, y^\prime) = 0$, 一阶隐式
# * $y^\prime = f(x,y)$, 一阶显式
# * $F(x, y, y^\prime,\ldots, y^{(n)}) = 0$, $n$ 阶隐式
# * $y^{(n)} = f(x, y, y^\prime, \ldots, y^{(n-1)})$, $n$ 阶显式

# %% [markdown]
# ## 线性和非线性微分方程

# %% [markdown]
# 如果方程 $F(x, y, y^\prime,\ldots, y^{(n)}) = 0$ 的左端为未知函数及其各阶导数的**一次有理整式**,则称它为
# **线性微分方程**,否则,称它为**非线性微分方程**。

# %% [markdown]
# $n$ 阶线性微分方程的一般形式为:
# $$
# a_0(x)y^{(n)}+a_1(x)y^{(n-1)}+\cdots+a_n(x)y=g(x)
# $$
# 其中 $a_0(x), a_1(x), \cdots, a_n(x), g(x)$ 均为 $x$ 的已知函数.

# %% [markdown]
# ## 解和隐式解

# %% [markdown]
# 对于方程
# $$F(x, y, y^\prime,\ldots, y^{(n)}) = 0$$
#
# 如果函数 $y = \varphi(x)$ 代入能使它变成恒等式, 则称 $y = \varphi(x)$ 为它的**解**.
#
# 如果关系式 $\Phi(x, y)=0$ 决定的函数 $y = \varphi(x)$ 是它的解, 则称 $\Phi(x, y)=0$ 为方程的**隐式解**, 也称为**"积分"**.

# %% [markdown]
# ## 通解和特解

# %% [markdown]
# 把 $n$ 阶方程
# $$F(x, y, y^\prime,\ldots, y^{(n)}) = 0$$
# 含有 $n$ 个独立的任意常数 $c_1, c_2, \cdots, c_n$的解
# $$ y = \varphi(x, c_1, c_2, \cdots, c_n)$$
# 称为它的**通解**.
#
# 要确定通解中的 $n$ 个常数, 得到一个特定的解, 需要 $n$ 个条件, 例如
#
# $$
# y(x_0) = y_0, \frac{dy(x_0)}{dx}=y_1, \cdots, \frac{d^{n-1}y(x_0)}{dx^{n-1}}=y_{n-1}.
# $$
#
# 上面 $n$ 条件称为**初值条件**.
#
# 求微分方程满足初值条件的解, 称为**初值问题**. 满足初值条件的解称为**特解**.

# %% [markdown]
# 所谓 $c_1, c_2, \cdots, c_n$ 独立， 其含义是 Jacobi 行列式
#
# $$
# \begin{vmatrix}
# \frac{\partial \varphi}{\partial c_1} & \frac{\partial \varphi}{\partial c_2} & \cdots & \frac{\partial \varphi}{\partial c_n}\\
# \frac{\partial \varphi'}{\partial c_1} & \frac{\partial \varphi'}{\partial c_2} & \cdots & \frac{\partial \varphi'}{\partial c_n}\\
# \vdots & \vdots & \ddots & \vdots \\
# \frac{\partial \varphi^{(n-1)}}{\partial c_1} & \frac{\partial \varphi^{(n-1)}}{\partial c_2} & \cdots & \frac{\partial \varphi^{(n-1)}}{\partial c_n}\\
# \end{vmatrix}
# \not= 0
# $$

# %% [markdown]
# 其中
# $$
# \begin{cases}
# \varphi = \varphi(x, c_1, c_2, \cdots, c_n), \\
# \varphi^{(1)} = \varphi^{(1)}(x, c_1, c_2, \cdots, c_n), \\
# \varphi^{(2)} = \varphi^{(2)}(x, c_1, c_2, \cdots, c_n), \\
# \vdots \\
# \varphi^{(n-1)} = \varphi^{(n-1)}(x, c_1, c_2, \cdots, c_n), \\
# \end{cases}
# $$

# %% [markdown]
# 由初值条件可得：
# $$
# \begin{cases}
#  y_0= \varphi(x_0, c_1, c_2, \cdots, c_n), \\
# y_1 = \varphi^{(1)}(x_0, c_1, c_2, \cdots, c_n), \\
# y_2 = \varphi^{(2)}(x_0, c_1, c_2, \cdots, c_n), \\
# \vdots \\
# y_{n-1} = \varphi^{(n-1)}(x_0, c_1, c_2, \cdots, c_n), \\
# \end{cases}
# $$

# %% [markdown]
# 由上面的 Jacobi 行列式不为 0, 则有多元反函数存在定理， 可得：
# $$
# \begin{cases}
# c_1= c_1(x_0, y_0, y_1, \cdots, y_{n-1}), \\
# c_2= c_2(x_0, y_0, y_1, \cdots, y_{n-1}), \\
# \vdots\\
# c_n= c_n(x_0, y_0, y_1, \cdots, y_{n-1}), \\
# \end{cases}
# $$

# %% [markdown]
# ## 积分曲线和积分曲线族

# %% [markdown]
# 一阶微分方程
# $$ \frac{dy}{dx}=f(x,y)$$
# 的解 $y=\varphi(x)$ 表示 $Oxy$ 平面上的一条曲线, 称为微分方程的**积分曲线**, 而其通解 $y=\varphi(x, c)$ 表示 $Oxy$ 平面上的一族曲线, 称为微分方程的**积分曲线族**.

# %% [markdown]
# ## 微分方程的几何解释-----方向场

# %% [markdown]
# 一阶微分方程
# $$ \frac{dy}{dx}=f(x,y)$$
# 设其右端函数 $f(x,y)$ 定义域为 $D$, 在 $D$ 的每一个点 $(x, y)$ 处画一个小线段, 其斜率等于 $f(x, y)$, 则点集 $D$就成为带方向的点集, 称其为方程 $\frac{dy}{dx}=f(x,y)$ 确定的**方向场**, 又称**向量场**.

# %% [markdown]
# 方向场中方向相同的曲线 $f(x,y)=k$, 称为**等倾斜线**或**等斜线**.

# %% [markdown]
# 常微分方程求解的几何意义: **在方向场中寻求一条曲线, 使这条曲线上每一点切线的方向等于方向场中该点的方向.**

# %% [markdown]
# **例 1** 画出 $\frac{dy}{dt}= y - t$ 的方向场.

# %%
def plotSlopeField(tdomain,ydomain,formula):
    # initialize figure
    fig = plt.figure(num=1)
 
    # create grid
    T,Y = np.meshgrid(tdomain,ydomain )
 
    # calculate direction vectors
    U = 1
    V = np.array([[formula.subs({y(t): yval, t: tval}) for tval in tdomain] for yval in ydomain],dtype = 'float')
    N = np.sqrt(U**2+V**2)
    U2, V2 = U/N, V/N
 
    # make the plot
    plt.quiver( T,Y,U2, V2)
    plt.xlabel(r"$t$")
    plt.ylabel(r"$y$")
    plt.axhline(0,0,1,linewidth = 1, color = 'black')
    plt.axvline(0,0,1,linewidth = 1, color = 'black')
 
    return fig

# %%
# %matplotlib inline
import numpy as np
from sympy.abc import t
from sympy import Function
import matplotlib.pyplot as plt
tdomain = np.linspace(-3,3,30)
ydomain = np.linspace(-3,3,30)

y = Function('y')
formula = y(t) - t
fg = plotSlopeField(tdomain,ydomain,formula)
fg.show()
# Out:
# /usr/local/lib/python3.5/dist-packages/matplotlib/figure.py:418: UserWarning: matplotlib is currently using a non-GUI backend, so cannot show the figure
#   "matplotlib is currently using a non-GUI backend, "

# %% [markdown]
# **例 2** 画出方程 $\frac{dy}{dt}=t^2+y^2$ 的方向场.

# %%
tdomain = np.linspace(-3,3,30)
ydomain = np.linspace(-3,3,30)

y = Function('y')
formula = t**2 + y(t)**2
fg = plotSlopeField(tdomain,ydomain,formula)
fg.show()
# Out:
# /usr/local/lib/python3.5/dist-packages/matplotlib/figure.py:418: UserWarning: matplotlib is currently using a non-GUI backend, so cannot show the figure
#   "matplotlib is currently using a non-GUI backend, "

# %% [markdown]
# ## 微分方程组

# %% [markdown]
# **微分方程组**: 用两个或两个以上关系式表示的微分方程.

# %% [markdown]
# 习惯将一般 $n$ 阶方程写成解出最高阶导数的形式
#
# $$ z^{(n)} = g(t;z, z^\prime, \cdots, z^{(n-1)})$$
#
# 取变换
#
# $$ y_1= z, y_2 = z^\prime, \cdots, y_n = z^{(n-1)} $$
#
# 可把$n$阶方程化为一阶方程组
#
# $$
# \begin{cases}
# \frac{dy_1}{dt}=y_2,\\
# \vdots \\
# \frac{dy_{n-1}}{dt}=y_n,\\
# \frac{dy_n}{dt} = g(t;y_1, \cdots, y_n)
# \end{cases}
# $$
#
# 一般的一阶微分方程组形式如下:
#
# $$ \frac{d\mathbf y}{dt}=\mathbf f(t;\mathbf y)$$
#
# 其中
#
# $$
# \mathbf y =
# \begin{pmatrix}
# y_1\\y_2\\\vdots\\y_n
# \end{pmatrix},\quad
# \mathbf f(t;\mathbf y) =
# \begin{pmatrix}
# f_1(t;y_1,\cdots,y_n)\\
# f_2(t;y_1,\cdots,y_n)\\
# \vdots\\
# f_n(t;y_1,\cdots,y_n)
# \end{pmatrix}
# $$

# %% [markdown]
# ## 驻定(autonomous)与非驻定, 动力系统

# %% [markdown]
# 如果方程右端不含自变量 $t$, 即
#
# $$ \frac{d\mathbf y}{dt}=\mathbf f(\mathbf y), \mathbf y \in D \subset \mathbb R^n$$
#
# 则称为**驻定(自治)的**, 若右端含 $t$ 则称为**非驻定(非自治)的**.
#
# 对于非驻定微分方程组, 可以引进新的时间 $\tau$, 方程组$ \frac{d\mathbf y}{dt}=\mathbf f(t; \mathbf y)$  可化为
#
# $$
# \begin{cases}
# \frac{d\mathbf y}{d\tau}=\mathbf f(t;\mathbf y)\\
# \frac{dt}{d\tau}=1,
# \end{cases}
# $$
# 成为 $n+1$ 维空间 $(t;\mathbf y)$ 驻定方程.

# %% [markdown]
# **驻定方程性质：** 设 $\mathbf y_1(t)$ 是
#
#  $$\frac{d\mathbf y}{dt}=\mathbf f(\mathbf y), \mathbf y(0) = \mathbf y_0$$
#
# 解, 则 $\mathbf y_2(t)= \mathbf y_1(t - t_0)$ 是
# $$\frac{d\mathbf y}{dt}=\mathbf f(\mathbf y), \mathbf y(t_0) = \mathbf y_0$$
# 的解.

# %% [markdown]
# 记 $s = t - t_0$, $\mathbf y_1(s) = \mathbf y_2(t)$, 并且 $ds = dt$， 从而有：

# %% [markdown]
# $$
# \frac{d\mathbf y_2(t) }{dt}= \frac{d\mathbf y_1(t - t_0) }{dt} = \frac{d\mathbf y_1(s) }{ds} = \mathbf f\left(\mathbf y_1(s)\right) = \mathbf f\left(\mathbf y_2(t)\right)
# $$

# %% [markdown]
# 进一步，容易验证：
#
# $$
# \mathbf y_2(t_0) = \mathbf y_1(t_0 - t_0) = \mathbf y_1(0) = \mathbf y_0
# $$

# %% [markdown]
# 引自**维基百科:**
# >在数学中，一个动力系统被称为自治（驻定）的，当且仅当这个系统由一组常微分方程组成，并且这些方程的表达式与动力系统的自变量无关。
#
# >在有关物理的动力系统中，自变量通常是时间。这时自治系统通常表示其中的物理规律不随时间变化的系统，也就是说空间中每一点的性质在过去、现在和将来都是一样的。
#
# >自治系统是动力系统中很重要的一个组成部分。理论上说，所有的动力系统都可以转化为自治系统。
